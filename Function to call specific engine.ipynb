# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Processed_Test_001.csv")
test = df[df['ID']==1]
test = test.drop(columns=['ID'])
X_test=test.iloc[:,:-1]
y_test=test.iloc[:,-1]

# %%
df=pd.read_csv("Processed_Test_001.csv")
df
# Out:
#         ID  Cycle  SensorMeasure2  SensorMeasure3  SensorMeasure4  \
# 0        1      1          643.02         1585.29         1398.21
# 1        1      2          641.71         1588.45         1395.42
# 2        1      3          642.46         1586.94         1401.34
# 3        1      4          642.44         1584.12         1406.42
# 4        1      5          642.51         1587.19         1401.92
# ...    ...    ...             ...             ...             ...
# 13091  100    194          643.24         1599.45         1415.79
# 13092  100    195          643.22         1595.69         1422.05
# 13093  100    196          643.44         1593.15         1406.82
# 13094  100    197          643.26         1594.99         1419.36
# 13095  100    198          642.95         1601.62         1424.99
#
#        SensorMeasure7  SensorMeasure8  SensorMeasure11  SensorMeasure12  \
# 0              553.90         2388.04            47.20           521.72
# ...

# %%
test = df[df['ID']==1]
test = test.drop(columns=['ID'])
X_test=test.iloc[:,:-1]
y_test=test.iloc[:,-1]

# %%
X_test
# Out:
#     Cycle  SensorMeasure2  SensorMeasure3  SensorMeasure4  SensorMeasure7  \
# 0       1          643.02         1585.29         1398.21          553.90
# 1       2          641.71         1588.45         1395.42          554.85
# 2       3          642.46         1586.94         1401.34          554.11
# 3       4          642.44         1584.12         1406.42          554.07
# 4       5          642.51         1587.19         1401.92          554.16
# 5       6          642.11         1579.12         1395.13          554.22
# 6       7          642.11         1583.34         1404.84          553.89
# 7       8          642.54         1580.89         1400.89          553.59
# 8       9          641.88         1593.29         1412.28          554.49
# 9      10          642.07         1585.25         1398.64          554.28
# 10     11          642.04         1581.03         1403.83          554.69
# 11     12          642.54         1587.43         1397.82          554.35
# ...

# %%
def give_engine(Test_no,engine_id):
    import pandas as pd
    import numpy as np
    df=pd.read_csv("Processed_Test_00{}.csv".format(Test_no))
    test = df[df['ID']==engine_id]
    test = test.drop(columns=['ID'])
    X_test=test.iloc[:,:-1]
    y_test=test.iloc[:,-1]
    return X_test,y_test

# %%
X_test,y_test=give_engine(1,1)

# %%
X_test
# Out:
#     Cycle  SensorMeasure2  SensorMeasure3  SensorMeasure4  SensorMeasure7  \
# 0       1          643.02         1585.29         1398.21          553.90
# 1       2          641.71         1588.45         1395.42          554.85
# 2       3          642.46         1586.94         1401.34          554.11
# 3       4          642.44         1584.12         1406.42          554.07
# 4       5          642.51         1587.19         1401.92          554.16
# 5       6          642.11         1579.12         1395.13          554.22
# 6       7          642.11         1583.34         1404.84          553.89
# 7       8          642.54         1580.89         1400.89          553.59
# 8       9          641.88         1593.29         1412.28          554.49
# 9      10          642.07         1585.25         1398.64          554.28
# 10     11          642.04         1581.03         1403.83          554.69
# 11     12          642.54         1587.43         1397.82          554.35
# ...
